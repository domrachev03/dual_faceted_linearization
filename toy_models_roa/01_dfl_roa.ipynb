# %% [markdown]
# # DFL applied to extended ROA analysis

# %%
from darli.models import RobotModel     # Rofl, bez nee casadi ne importiruetsya
import casadi as cs
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.integrate import solve_ivp
from utils import draw_elipse, phase_portrait, sampling_roa

# %% [markdown]
# ## Inverted time Van der Pol oscillator

# %% [markdown]
# The equation is:
# $$\ddot{x} = -(1-x^2)\dot{v} - x + u$$
#
# For the DFL linearization, let's choose:
# $$\eta = \begin{bmatrix} x^2 \dot{x} \end{bmatrix}.$$

# %% [markdown]
# If we introduce $q = \begin{bmatrix} x \\ \dot{x} \end{bmatrix}$
# Then, the equation would be:
# $$\dot{q} = \begin{bmatrix} 0 & 1 \\ -1 & -1 \end{bmatrix} q + \begin{bmatrix} 0 \\ 1 \end{bmatrix} \eta + \begin{bmatrix} 0 \\ 1 \end{bmatrix} u \equiv A_q q + A_\eta \eta + Bu$$

# %%
nx, nv, neta = 1, 1, 1

x = cs.SX.sym('x', nx)
v = cs.SX.sym('v', nv)
dv = cs.SX.sym('dv', nv)

state = cs.vertcat(x, v)
state_dot = cs.vertcat(v, dv)

# %%
# Inverted-time Van der Pol no. 1
# f = cs.Function("f", [state], [cs.vertcat(v, -(1-x**2)*v - x)])
# eta = x**2 * v
# A_x = np.array([[0, 1], [-1, -1]])
# A_eta = np.array([0, 1]).reshape(-1, 1)

# Inverted-time Van der Pol no. 2
f = cs.Function("f", [state], [cs.vertcat(v, -x-v + (x**3)/3)])
eta = x**3 / 3
A_x = np.array([[0, 1], [-1, -1]])
A_eta = np.array([0, 1]).reshape(-1, 1)

# Pendulum
# f = cs.Function("f", [state], [cs.vertcat(v, -9.81 * cs.sin(x))])
# eta = -cs.sin(x)
# A_x = np.array([[0, 1], [0, 0]])
# A_eta = np.array([0, 9.81]).reshape(-1, 1)

# Random example 1
# f = cs.Function("f", [state], [cs.vertcat(v, -2*x -3*v + x**2*v)])
# eta = x**2 * v
# A_x = np.array([[0, 1], [-2, -3]])
# A_eta = np.array([0, 1]).reshape(-1, 1)

# Random example 2
# f = cs.Function('f', [state], [cs.vertcat(-50*x - 16*v + 13.8*x*v, 13*x-9*v+5.5*x*v)])
# eta = x*v
# A_x = np.array([[-50, -16], [13, -9]])
# A_eta = np.array([13.8, 5.5]).reshape(-1, 1)

# Random non-polynomial example
# x_eq, v_eq = 0.02801, 0.06403
# f = cs.Function("f", [state], [cs.vertcat(-cs.sin(x-x_eq)-0.5*cs.sin(x-x_eq-v+v_eq), -0.5*cs.sin(v-v_eq)+0.5*cs.sin(x-x_eq - v+v_eq))])
# eta = cs.vertcat(cs.sin(x-x_eq), cs.sin(v-v_eq), cs.sin(x-x_eq-v+v_eq))
# neta = 3
# A_x = np.array([[0, 0], [0, 0]])
# A_eta = np.array([[-1, 0, -0.5], [0, -0.5, 0.5]])

# %%
n_state = nx + nv
n_full_state = n_state + neta

# %%
# There would be two types of symbolic etas: eta(x) and eta as free variable
# It's important to note where which variable is used
eta_sym = cs.SX.sym('eta', neta)

# %%
eta_fn = cs.Function("eta", [state], [eta])

# State + auxiliary variables
full_state = cs.vertcat(state, eta)
full_state_sym = cs.vertcat(state, eta_sym)

# %%
# Verification that matrices are chosed correctly
f_lin = cs.Function("f_lin", [state], [A_x @ state + A_eta @ eta])

state_np = np.random.uniform(-2, 2, size=(n_state,))

f_lin(state_np), f(state_np)
# Out:
# (DM([-0.429622, 0.981451]), DM([-0.429622, 0.981451]))

# %% [markdown]
# ### Data sampling

# %%
# Simulation parameters
dt_sim = 1e-3
dt_sample = 1e-1
n_samples = 100
t_end = 10
x_range = (-2, 2)
v_range = (-2, 2)

# %%
ts = np.arange(0, t_end, dt_sim)
save_each = int(dt_sample / dt_sim)
state_samples = []

f_np = lambda t, x: np.array(f(x)).ravel()

progress_bar = tqdm(total=n_samples)

while len(state_samples) < n_samples:
    state_np = np.array([
        np.random.uniform(*x_range),
        np.random.uniform(*v_range)
    ])
    sol = solve_ivp(
        f_np,
        (0, t_end),
        state_np,
        t_eval=ts
    )
    if sol.status == 0:
        progress_bar.update(1)
        state_samples.append(sol.y.T[::save_each])
progress_bar.close()
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 99.66it/s]

# %%
state_np = np.concatenate(state_samples, axis=0)
v_dot_np = np.array([
    f_np(0, state_i) for state_i in state_np
])
# It's not multiple of n_samples, because some samples diverged and did not finish the iteration
state_np.shape
# Out:
# (10000, 2)

# %%
eta_dot = cs.jacobian(eta, state) @ cs.vertcat(v, dv)
eta_dot_fn = cs.Function(
    "eta_dot", 
    [state, dv], 
    [
        eta_dot
    ]
)

eta_np = np.array([
    eta_fn(state_i) for state_i in state_np
])[:, :, 0]
eta_np.shape
# Out:
# (10000, 1)

# %%
eta_dot_np = np.array([
    eta_dot_fn(state_i, v_dot_i[1]) for state_i, v_dot_i in zip(state_np, v_dot_np)
])[:, :, 0]
eta_dot_np.shape
# Out:
# (10000, 1)

# %%
full_state_np = np.concatenate([state_np, eta_np], axis=1)

full_state_np.shape
# Out:
# (10000, 3)

# %%
H_w_cp = cp.Variable((neta, n_full_state))
objective_samples = 1/len(full_state_np) * cp.sum_squares(eta_dot_np.T - H_w_cp@full_state_np.T)
problem_samples = cp.Problem(cp.Minimize(objective_samples))
problem_samples.solve(solver=cp.OSQP, verbose=True)

H_w = H_w_cp.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Jan 24 06:18:36 AM: Your problem has 3 variables, 0 constraints, and 0 parameters.
# (CVXPY) Jan 24 06:18:36 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 24 06:18:36 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 24 06:18:36 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jan 24 06:18:36 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 24 06:18:36 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Jan 24 06:18:36 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Jan 24 06:18:36 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 24 06:18:36 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jan 24 06:18:36 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Jan 24 06:18:36 AM: Applying reduction OSQP
# (CVXPY) Jan 24 06:18:36 AM: Finished problem compilation (took 2.876e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 24 06:18:36 AM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 10003, constraints m = 10000
#           nnz(P) + nnz(A) = 50000
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   6.67e+00   4.44e+04   1.00e-01   4.26e-03s
#   50   3.0170e-02   3.45e-07   5.98e-07   1.75e-03   1.80e-02s
# plsh   3.0170e-02   6.49e-16   4.93e-14   --------   2.13e-02s
#
# status:               solved
# solution polish:      successful
# number of iterations: 50
# optimal objective:    0.0302
# run time:             2.13e-02s
# optimal rho estimate: 2.14e-05
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jan 24 06:18:36 AM: Problem status: optimal
# (CVXPY) Jan 24 06:18:36 AM: Optimal value: 3.017e-02
# (CVXPY) Jan 24 06:18:36 AM: Compilation took 2.876e-02 seconds
# (CVXPY) Jan 24 06:18:36 AM: Solver (including time spent in interface) took 2.436e-02 seconds

# %%
t_end = 50
t_sim = 1e-3
ts = np.arange(0, t_end, t_sim)

# %%
def f_lin(t, x):
    state, eta = x[:-neta], x[-neta:]
    state_dot = A_x @ state + A_eta @ eta
    eta_dot = H_w @ x
    return np.concatenate([state_dot, eta_dot])

# state_np = np.random.uniform(-2, 2, size=(2, ))
state_np = np.array([1, 1])
eta_np = np.array(eta_fn(state_np)).ravel()

full_state_np = np.concatenate([state_np, eta_np], axis=0)

sol = solve_ivp(
    f_np,
    (0, t_end),
    state_np,
    t_eval=ts
)

lin_sol = solve_ivp(
    f_lin,
    (0, t_end),
    full_state_np,
    t_eval=ts
)

# %%
sol.y.shape, lin_sol.y.shape
# Out:
# ((2, 50000), (3, 50000))

# %%
lin_sol.y.shape
# Out:
# (3, 50000)

# %%
fig, ax = plt.subplots(3, 1, figsize=(12, 8))
# sol.y = sol.y[:, :1000]
for i in range(2):
    ax[i].plot(ts[:len(lin_sol.y[i])], lin_sol.y[i], label=f"q{i} DFL")
    ax[i].set_title('Positions')
    ax[i].plot(ts[:len(sol.y[i])], sol.y[i], label=f"q{i} real")
    ax[i].legend()
eta_sol = np.array(
    [eta_fn(state_i) for state_i in sol.y.T]
)[:, :, 0]
ax[2].set_title('Auxiliary Variable')
ax[2].plot(ts[:len(lin_sol.y.T)], lin_sol.y.T[:, n_state:], label=f"eta DFL")
ax[2].plot(ts[:len(eta_sol)], eta_sol, label="eta real")
ax[2].legend()
plt.show()

# %% [markdown]
# ## Regions of Attraction

# %% [markdown]
# ### LTI LQR

# %% [markdown]
# $$V = \frac{1}{2} x^T P x$$

# %% [markdown]
# Now, let's analyse the following Lyapunov candidate:
# $$V = \frac{1}{2} \eta^T P \eta,$$
# where $P$ is a matrix, resulting from LTI LQR discrete control.

# %%
A = np.zeros(((n_full_state, n_full_state)))
A[:n_state, :n_state] = A_x
A[:n_state, n_state:] = A_eta
A[n_state:] = H_w

# %%
from scipy.linalg import solve_continuous_lyapunov as lyap

Q = np.eye(n_full_state) * 2
P = lyap(A.T, -Q)

# %%
P
# Out:
# array([[ 3.57952803,  0.89585645, -0.55983772],
#        [ 0.89585645,  2.80930882,  2.02974612],
#        [-0.55983772,  2.02974612,  3.46052611]])

# %%
def is_pos_def(A):
    if np.allclose(A, A.T, rtol=1e-3):
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            print('Symmetric, but not p.d.')
            return False
    else:
        print('Not symmetric')
        return False

is_pos_def(P)
# Out:
# True

# %%
V = full_state.T @ P @ full_state
V_fn = cs.Function('V', [state], [V])
V_dot_fn = cs.Function('V_dot', [state], [cs.jacobian(V, state) @ f(state)])

# %%
state_lims = np.array([
    [-5, -5],
    [5, 5]
])

r_dfl, _ = sampling_roa(f, V_fn, V_dot_fn, state_lims, N = 10000)
levelset_dfl = cs.Function('V_level', [state], [V - r_dfl])
r_dfl
# Out:
# DM(9.54098)

# %%
jacobian = cs.Function('jacobian', [state], [cs.jacobian(f(state), state)])
A_taylor = jacobian(np.zeros(2))
Q_taylor = np.eye(2)

P_taylor = lyap(A_taylor.T, -Q_taylor)

V_taylor = state.T @ P_taylor @ state
V_taylor_fn = cs.Function('V_taylor', [state], [V_taylor])
V_taylor_dot_fn = cs.Function('V_taylor', [state], [cs.jacobian(V_taylor, state) @ f(state)])

# %%
r_taylor, _ = sampling_roa(f, V_taylor_fn, V_taylor_dot_fn, state_lims, N = 10000)
levelset_taylor = cs.Function('V_level', [state], [V_taylor - r_taylor])
r_taylor
# Out:
# DM(3.90091)

# %%
fig, ax = plt.subplots()

xlim = 4

phase_portrait(f, ax=ax, x_range=[xlim, xlim], density=1.2)
draw_elipse(
    [-xlim, xlim], 
    ax=ax,
    f = levelset_taylor, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'red',
    } 
)

draw_elipse(
    [-xlim, xlim], 
    ax=ax,
    f = levelset_dfl, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'blue',
    } 
)

plt.show()
