# %% [markdown]
# # DFL + Koopman applied to extended ROA analysis

# %%
from darli.models import RobotModel     # Rofl, bez nee casadi ne importiruetsya
import casadi as cs
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.integrate import solve_ivp
from utils import draw_elipse, phase_portrait, sampling_roa

# %% [markdown]
# ## Inverted time Van der Pol oscillator

# %% [markdown]
# The equation is:
# $$\ddot{x} = -(1-x^2)\dot{v} - x + u$$
#
# For the DFL linearization, let's choose:
# $$\eta = \begin{bmatrix} x^2 \dot{x} \end{bmatrix}.$$

# %% [markdown]
# If we introduce $q = \begin{bmatrix} x \\ \dot{x} \end{bmatrix}$
# Then, the equation would be:
# $$\dot{q} = \begin{bmatrix} 0 & 1 \\ -1 & -1 \end{bmatrix} q + \begin{bmatrix} 0 \\ 1 \end{bmatrix} \eta + \begin{bmatrix} 0 \\ 1 \end{bmatrix} u \equiv A_q q + A_\eta \eta + Bu$$

# %%
nx, nv = 1, 1

x = cs.SX.sym('x', nx)
v = cs.SX.sym('v', nv)
dv = cs.SX.sym('dv', nv)

state = cs.vertcat(x, v)
state_dot = cs.vertcat(v, dv)

# %%
neta_dfl = 1
neta_rbf = 20

# Inverted-time Van der Pol no. 1
# f = cs.Function("f", [state], [cs.vertcat(v, -(1-x**2)*v - x)])
# eta = x**2 * v
# A_x = np.array([[0, 1], [-1, -1]])
# A_eta = np.array([0, 1]).reshape(-1, 1)

# Inverted-time Van der Pol no. 2
f = cs.Function("f", [state], [cs.vertcat(v, -x-v + (x**3)/3)])
eta = x**3 / 3
A_x = np.array([[0, 1], [-1, -1]])
A_eta = np.array([0, 1]).reshape(-1, 1)

# Pendulum
# f = cs.Function("f", [state], [cs.vertcat(v, -9.81 * cs.sin(x))])
# eta = -cs.sin(x)
# A_x = np.array([[0, 1], [0, 0]])
# A_eta = np.array([0, 9.81]).reshape(-1, 1)

x0_range = (-1, 1)
x0 = cs.SX.sym('x0', nx+nv)
rbf = cs.Function('psi', [state, x0], [cs.norm_2(state - x0)**2 * cs.log(cs.norm_2(state - x0)) - cs.norm_2(x0)**2 * cs.log(cs.norm_2(x0))])
random_rbfs = [
    rbf(state, np.random.uniform(*x0_range, size=(nx+nv))) 
    for _ in range(neta_rbf)
]
eta = cs.vertcat(eta, *random_rbfs)
neta = neta_dfl + neta_rbf

# %%
# There would be two types of symbolic etas: eta(x) and eta as free variable
# It's important to note where which variable is used
eta_sym = cs.SX.sym('eta', neta)

# %%
eta_fn = cs.Function("eta", [state], [eta])

# State + auxiliary variables
full_state = cs.vertcat(state, eta)
full_state_sym = cs.vertcat(state, eta_sym)

# %%
# Verification that matrices are chosed correctly
f_lin = cs.Function("f_lin", [state], [A_x @ state + A_eta @ eta[:neta_dfl]])

state_np = np.random.uniform(-2, 2, size=(2,))

f_lin(state_np), f(state_np)
# Out:
# (DM([-0.171354, 0.313108]), DM([-0.171354, 0.313108]))

# %% [markdown]
# ### Data sampling

# %%
# Simulation parameters
dt_sim = 1e-3
dt_sample = 1e-1
n_samples = 100
t_end = 10
x_range = (-5, 5)

# %%
ts = np.arange(0, t_end, dt_sim)
save_each = int(dt_sample / dt_sim)
state_samples = []

f_np = lambda t, x: np.array(f(x)).ravel()

progress_bar = tqdm(total=n_samples)

while len(state_samples) < n_samples:
    state_np = np.random.uniform(*x_range, size=(2,))
    sol = solve_ivp(
        f_np,
        (0, t_end),
        state_np,
        t_eval=ts
    )
    if sol.status == 0:
        progress_bar.update(1)
        state_samples.append(sol.y.T[::save_each])
progress_bar.close()
# Out:
# 100%|██████████| 100/100 [00:13<00:00,  7.25it/s]

# %%
state_np = np.concatenate(state_samples, axis=0)
v_dot_np = np.array([
    f_np(0, state_i) for state_i in state_np
])
# It's not multiple of n_samples, because some samples diverged and did not finish the iteration
state_np.shape
# Out:
# (10000, 2)

# %%
eta_dot = cs.jacobian(eta, state) @ cs.vertcat(v, dv)
eta_dot_fn = cs.Function(
    "eta_dot", 
    [state, dv], 
    [
        eta_dot
    ]
)

eta_np = np.array([
    eta_fn(state_i) for state_i in state_np
])[:, :, 0]

# %%
eta_dot_np = np.array([
    eta_dot_fn(state_i, v_dot_i[1]) for state_i, v_dot_i in zip(state_np, v_dot_np)
])[:, :, 0]

# %%
full_state_np = np.concatenate([state_np, eta_np], axis=1)

full_state_np.shape
# Out:
# (10000, 23)

# %%
H_w_cp = cp.Variable((neta, nx+nv+neta))
objective_samples = 1/len(full_state_np) * cp.sum_squares(eta_dot_np.T - H_w_cp@full_state_np.T) #+ cp.norm(H_w_cp)
problem_samples = cp.Problem(cp.Minimize(objective_samples))
result = problem_samples.solve(verbose=True)

H_w = H_w_cp.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.1
# ===============================================================================
# (CVXPY) Dec 24 01:48:10 PM: Your problem has 483 variables, 0 constraints, and 0 parameters.
# (CVXPY) Dec 24 01:48:10 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Dec 24 01:48:10 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Dec 24 01:48:10 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Dec 24 01:48:10 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Dec 24 01:48:10 PM: Compiling problem (target solver=OSQP).
# (CVXPY) Dec 24 01:48:10 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Dec 24 01:48:10 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Dec 24 01:48:10 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Dec 24 01:48:10 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Dec 24 01:48:12 PM: Applying reduction OSQP
# (CVXPY) Dec 24 01:48:13 PM: Finished problem compilation (took 2.510e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Dec 24 01:48:13 PM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 210483, constraints m = 210000
#           nnz(P) + nnz(A) = 5250000
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   5.77e+02   3.50e+06   1.00e-01   3.03e+00s
#   50  -1.0000e+30   2.47e-06   1.09e-04   1.00e-01   4.79e+00s
#
# status:               dual infeasible
# number of iterations: 50
# run time:             4.82e+00s
# optimal rho estimate: 7.32e-04
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Dec 24 01:48:18 PM: Problem status: unbounded
# (CVXPY) Dec 24 01:48:18 PM: Optimal value: -inf
# (CVXPY) Dec 24 01:48:18 PM: Compilation took 2.510e+00 seconds
# (CVXPY) Dec 24 01:48:18 PM: Solver (including time spent in interface) took 4.886e+00 seconds

# %%
t_end = 10
ts = np.arange(0, t_end, dt_sim)
def f_lin(t, x):
    state, eta = x[:nx+nv], x[nx+nv:]
    state_dot = A_x @ state + A_eta @ eta[:neta_dfl]
    eta_dot = H_w @ x

    return np.concatenate([state_dot, eta_dot])

# state_np = np.random.uniform(-2, 2, size=(2, ))
state_np = np.array([-1, 2])
eta_np = np.array(eta_fn(state_np)).ravel()

full_state_np = np.concatenate([state_np, eta_np], axis=0)

sol = solve_ivp(
    f_np,
    (0, t_end),
    state_np,
    t_eval=ts
)

lin_sol = solve_ivp(
    f_lin,
    (0, t_end),
    full_state_np,
    t_eval=ts
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 23
#      14 full_state_np = np.concatenate([state_np, eta_np], axis=0)
#      16 sol = solve_ivp(
#      17     f_np,
#      18     (0, t_end),
#      19     state_np,
#      20     t_eval=ts
#      21 )
# ---> 23 lin_sol = solve_ivp(
#      24     f_lin,
#      25     (0, t_end),
#      26     full_state_np,
#      27     t_eval=ts
#      28 )
#
# File ~/miniconda3/envs/darli/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py:568, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     565 if method in METHODS:
#     566     method = METHODS[method]
# --> 568 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     570 if t_eval is None:
#     571     ts = [t0]
#
# File ~/miniconda3/envs/darli/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py:94, in RungeKutta.__init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      92 self.max_step = validate_max_step(max_step)
#      93 self.rtol, self.atol = validate_tol(rtol, atol, self.n)
# ---> 94 self.f = self.fun(self.t, self.y)
#      95 if first_step is None:
#      96     self.h_abs = select_initial_step(
#      97         self.fun, self.t, self.y, self.f, self.direction,
#      98         self.error_estimator_order, self.rtol, self.atol)
#
# File ~/miniconda3/envs/darli/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File ~/miniconda3/envs/darli/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# Cell In[14], line 6, in f_lin(t, x)
#       4 state, eta = x[:nx+nv], x[nx+nv:]
#       5 state_dot = A_x @ state + A_eta @ eta[:neta_dfl]
# ----> 6 eta_dot = H_w @ x
#       8 return np.concatenate([state_dot, eta_dot])
#
# ValueError: matmul: Input operand 0 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)

# %%
sol.y.shape, lin_sol.y.shape
# Out:
# ((2, 10000), (23, 10000))

# %%
fig, ax = plt.subplots(3, 1, figsize=(12, 8))
# sol.y = sol.y[:, :1000]
for i in range(2):
    ax[i].plot(ts[:len(lin_sol.y[i])], lin_sol.y[i], label=f"q{i} DFL")
    ax[i].set_title('Positions')
    ax[i].plot(ts[:len(sol.y[i])], sol.y[i], label=f"q{i} real")
    ax[i].legend()
eta_sol = np.array(
    [eta_fn(state_i) for state_i in sol.y.T]
).reshape(-1, 1)
ax[2].set_title('Auxiliary Variable')
ax[2].plot(ts[:len(lin_sol.y[-1])], lin_sol.y[-1], label=f"eta DFL")
# ax[2].plot(ts, eta_sol[0], label="eta real")
ax[2].legend()
plt.show()

# %% [markdown]
# ## Regions of Attraction

# %% [markdown]
# ### LTI LQR

# %% [markdown]
# Now, let's analyse the following Lyapunov candidate:
# $$V = \frac{1}{2} \eta^T P \eta,$$
# where $P$ is a matrix, resulting from LTI LQR discrete control.

# %%
A = np.zeros(((nx+nv+neta, nx+nv+neta)))
A[:nx+nv, :nx+nv] = A_x
A[:nx+nv, nx+nv:nx+nv+neta_dfl] = A_eta
A[nx+nv:] = H_w

# %%
from scipy.linalg import solve_continuous_lyapunov as lyap

Q = np.eye(nx+nv+neta)
P = lyap(A.T, -Q)

# %%
def is_pos_def(A):
    if np.allclose(A, A.T, rtol=1e-3):
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            print('Symmetric, but not p.d.')
            return False
    else:
        print('Not symmetric')
        return False

is_pos_def(P)
# Out:
# True

# %%
def sampling_roa(f, V, dV, x_bounds, N=100):
    x_min, x_max = x_bounds
    x_range = np.array(x_max) - np.array(x_min)
    n = np.shape(x_min)[0]

    c = np.inf
    ct = []

    for i in range(N):
        x_i = x_min + x_range*np.random.rand(n)
        dV_i = dV(x_i)
        V_i = V(x_i)
        if dV_i >= 0 and V_i <= c:
            c = V_i
            ct.append(c)  
    
    return c, np.array(ct)

# %%
V = 1/2 * full_state.T @ P @ full_state
V_fn = cs.Function('V', [state], [V])
V0 = V_fn(np.zeros(nx+nv))

V_dot_fn = cs.Function('V_dot', [state], [cs.jacobian(V, state) @ f(state)])

# %%
state_lims = np.array([
    [-2, -2],
    [2, 2]
])

r_dfl, _ = sampling_roa(f, V_fn, V_dot_fn, state_lims, N = 10000)
levelset_dfl = cs.Function('V_level', [state], [V - r_dfl])
r_dfl
# Out:
# DM(6.40987)

# %%
jacobian = cs.Function('jacobian', [state], [cs.jacobian(f(state), state)])
A_taylor = jacobian(np.zeros(2))
Q_taylor = np.eye(2)

P_taylor = lyap(A_taylor.T, -Q_taylor)

V_taylor = 1/2 * state.T @ P_taylor @ state
V_taylor_fn = cs.Function('V_taylor', [state], [V_taylor])
V_taylor_dot_fn = cs.Function('V_taylor', [state], [cs.jacobian(V_taylor, state) @ f(state)])

# %%
r_taylor, _ = sampling_roa(f, V_taylor_fn, V_taylor_dot_fn, state_lims, N = 10000)
levelset_taylor = cs.Function('V_level', [state], [V_taylor - r_taylor])
r_taylor
# Out:
# DM(1.15755)

# %%
phase_portrait(f, x_range=[3, 3], density=1.2)
draw_elipse(
    [-3, 3], 
    f = levelset_taylor, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'red',
    } 
)

draw_elipse(
    [-3, 3], 
    f = levelset_dfl, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'blue',
    } 
)

plt.show()
