# %% [markdown]
# # DFL + Koopman applied to extended ROA analysis

# %%
from darli.models import RobotModel     # Rofl, bez nee casadi ne importiruetsya
import casadi as cs
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.integrate import solve_ivp
from utils import draw_elipse, phase_portrait, sampling_roa

# %% [markdown]
# ## Inverted time Van der Pol oscillator

# %% [markdown]
# The equation is:
# $$\ddot{x} = -(1-x^2)\dot{v} - x + u$$
#
# For the DFL linearization, let's choose:
# $$\eta = \begin{bmatrix} x^2 \dot{x} \end{bmatrix}.$$

# %% [markdown]
# If we introduce $q = \begin{bmatrix} x \\ \dot{x} \end{bmatrix}$
# Then, the equation would be:
# $$\dot{q} = \begin{bmatrix} 0 & 1 \\ -1 & -1 \end{bmatrix} q + \begin{bmatrix} 0 \\ 1 \end{bmatrix} \eta + \begin{bmatrix} 0 \\ 1 \end{bmatrix} u \equiv A_q q + A_\eta \eta + Bu$$

# %%
nx, nv = 1, 1

x = cs.SX.sym('x', nx)
v = cs.SX.sym('v', nv)
dv = cs.SX.sym('dv', nv)

state = cs.vertcat(x, v)
state_dot = cs.vertcat(v, dv)

# %%
neta_dfl = 1
neta_rbf = 20

# Inverted-time Van der Pol no. 1
f = cs.Function("f", [state], [cs.vertcat(v, -(1-x**2)*v - x)])
eta = x**2 * v
A_x = np.array([[0, 1], [-1, -1]])
A_eta = np.array([0, 1]).reshape(-1, 1)

# Inverted-time Van der Pol no. 2
# f = cs.Function("f", [state], [cs.vertcat(v, -x-v + (x**3)/3)])
# eta = x**3 / 3
# A_x = np.array([[0, 1], [-1, -1]])
# A_eta = np.array([0, 1]).reshape(-1, 1)

# Pendulum
# f = cs.Function("f", [state], [cs.vertcat(v, -9.81 * cs.sin(x))])
# eta = -cs.sin(x)
# A_x = np.array([[0, 1], [0, 0]])
# A_eta = np.array([0, 9.81]).reshape(-1, 1)

x0_range = (-1, 1)
x0 = cs.SX.sym('x0', nx)
rbf = cs.Function('psi', [x, x0], [cs.norm_2(x - x0)**2 * cs.log(cs.norm_2(x - x0))])
random_rbfs = [
    rbf(x, np.random.uniform(*x0_range)) 
    for _ in range(neta_rbf)
]
eta = cs.vertcat(eta, *random_rbfs)
neta = neta_dfl + neta_rbf

# %%
# There would be two types of symbolic etas: eta(x) and eta as free variable
# It's important to note where which variable is used
eta_sym = cs.SX.sym('eta', neta)

# %%
eta_fn = cs.Function("eta", [state], [eta])

# State + auxiliary variables
full_state = cs.vertcat(state, eta)
full_state_sym = cs.vertcat(state, eta_sym)

# %%
# Verification that matrices are chosed correctly
f_lin = cs.Function("f_lin", [state], [A_x @ state + A_eta @ eta[:neta_dfl]])

state_np = np.random.uniform(-2, 2, size=(2,))

f_lin(state_np), f(state_np)
# Out:
# (DM([0.702098, 3.74079]), DM([0.702098, 3.74079]))

# %% [markdown]
# ### Data sampling

# %%
# Simulation parameters
dt_sim = 1e-3
dt_sample = 1e-1
n_samples = 100
t_end = 10
x_range = (-5, 5)

# %%
ts = np.arange(0, t_end, dt_sim)
save_each = int(dt_sample / dt_sim)
state_samples = []

f_np = lambda t, x: np.array(f(x)).ravel()

progress_bar = tqdm(total=n_samples)

while len(state_samples) < n_samples:
    state_np = np.random.uniform(*x_range, size=(2,))
    sol = solve_ivp(
        f_np,
        (0, t_end),
        state_np,
        t_eval=ts
    )
    if sol.status == 0:
        progress_bar.update(1)
        state_samples.append(sol.y.T[::save_each])
progress_bar.close()
# Out:
# 100%|██████████| 100/100 [00:29<00:00,  3.34it/s]

# %%
state_np = np.concatenate(state_samples, axis=0)
v_dot_np = np.array([
    f_np(0, state_i) for state_i in state_np
])
# It's not multiple of n_samples, because some samples diverged and did not finish the iteration
state_np.shape
# Out:
# (10000, 2)

# %%
eta_dot = cs.jacobian(eta, state) @ cs.vertcat(v, dv)
eta_dot_fn = cs.Function(
    "eta_dot", 
    [state, dv], 
    [
        eta_dot
    ]
)

eta_np = np.array([
    eta_fn(state_i) for state_i in state_np
])[:, :, 0]

# %%
eta_dot_np = np.array([
    eta_dot_fn(state_i, v_dot_i[1]) for state_i, v_dot_i in zip(state_np, v_dot_np)
])[:, :, 0]

# %%
full_state_np = np.concatenate([state_np, eta_np], axis=1)

full_state_np.shape
# Out:
# (10000, 23)

# %%
H_w_cp = cp.Variable((neta, nx+nv+neta))
objective_samples = 1/len(full_state_np) * cp.sum_squares(eta_dot_np.T - H_w_cp@full_state_np.T) + cp.norm(H_w_cp)
problem_samples = cp.Problem(cp.Minimize(objective_samples))
result = problem_samples.solve(verbose=True)

H_w_np = H_w_cp.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.1
# ===============================================================================
# (CVXPY) Dec 22 02:29:48 PM: Your problem has 483 variables, 0 constraints, and 0 parameters.
# (CVXPY) Dec 22 02:29:48 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Dec 22 02:29:48 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Dec 22 02:29:48 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Dec 22 02:29:48 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Dec 22 02:29:48 PM: Compiling problem (target solver=SCS).
# (CVXPY) Dec 22 02:29:48 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Dec 22 02:29:48 PM: Applying reduction Dcp2Cone
# (CVXPY) Dec 22 02:29:48 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Dec 22 02:29:48 PM: Applying reduction Dcp2Cone
# (CVXPY) Dec 22 02:29:48 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Dec 22 02:29:48 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Dec 22 02:29:52 PM: Applying reduction SCS
# (CVXPY) Dec 22 02:29:53 PM: Finished problem compilation (took 4.749e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Dec 22 02:29:53 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 485, constraints m: 210992
# cones: 	  q: soc vars: 210002, qsize: 1
# 	  s: psd vars: 990, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 4830529, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.53e+02  1.05e+01  5.83e+03  2.92e+03  1.00e-01  4.16e+00
#    250| 2.98e+01  9.46e-03  2.09e+01  6.75e+00  5.97e-06  1.51e+01
#    500| 4.71e+01  3.91e-04  7.60e+00 -1.39e+01  1.00e-06  2.39e+01
#    750| 8.35e+00  7.00e-06  1.35e+00  5.55e-01  1.00e-06  3.09e+01
#   1000| 1.03e+01  4.30e-06  1.68e+00  5.62e-01  1.00e-06  3.78e+01
#   1250| 1.07e+01  1.13e-05  1.73e+00  7.95e-01  1.00e-06  4.47e+01
#   1500| 4.07e+00  3.39e-06  6.58e-01  5.98e+00  1.00e-06  5.18e+01
#   1750| 3.77e+00  1.30e-05  3.22e-01  7.74e+00  1.00e-06  5.90e+01
#   2000| 3.67e+00  6.59e-07  3.95e-01  6.77e+00  1.00e-06  6.63e+01
#   2250| 2.75e+00  1.66e-05  1.50e-01  8.71e+00  1.00e-06  7.35e+01
#   2500| 2.66e+00  5.12e-06  2.57e-01  7.93e+00  1.00e-06  8.12e+01
#   2750| 3.08e+00  1.58e-06  3.16e-01  7.88e+00  1.00e-06  8.93e+01
#   3000| 2.21e+00  2.60e-06  8.67e-02  8.29e+00  1.00e-06  9.63e+01
#   3250| 2.18e+00  8.36e-07  8.78e-02  8.19e+00  1.00e-06  1.03e+02
#   3500| 2.13e+00  9.66e-07  7.13e-02  8.24e+00  1.00e-06  1.10e+02
#   3750| 2.11e+00  8.68e-07  6.69e-02  8.24e+00  1.00e-06  1.17e+02
#   4000| 2.06e+00  1.05e-06  5.49e-02  8.28e+00  1.00e-06  1.24e+02
#   4250| 2.04e+00  8.44e-07  4.96e-02  8.29e+00  1.00e-06  1.31e+02
#   4500| 1.98e+00  4.57e-07  3.75e-02  8.31e+00  1.00e-06  1.38e+02
#   4750| 1.98e+00  3.00e-07  3.76e-02  8.30e+00  1.00e-06  1.45e+02
#   5000| 1.94e+00  4.63e-07  2.76e-02  8.34e+00  1.00e-06  1.52e+02
#   5250| 1.89e+00  1.15e-07  1.94e-02  8.37e+00  1.00e-06  1.59e+02
#   5500| 1.82e+00  4.41e-07  1.36e-02  8.44e+00  3.18e-06  1.68e+02
#   5750| 1.63e+00  8.10e-06  1.39e-01  8.80e+00  2.74e-05  1.76e+02
#   6000| 1.44e+00  7.36e-06  1.33e-01  9.07e+00  2.74e-05  1.86e+02
#   6250| 1.27e+00  6.68e-06  1.27e-01  9.33e+00  2.74e-05  1.95e+02
#   6500| 1.13e+00  6.07e-06  1.21e-01  9.57e+00  2.74e-05  2.02e+02
#   6750| 9.91e-01  2.11e-05  1.53e-01  9.94e+00  2.74e-05  2.09e+02
#   7000| 9.77e-01  4.73e-06  8.83e-02  1.02e+01  2.74e-05  2.15e+02
#   7250| 9.40e-01  4.24e-06  3.35e-03  1.04e+01  2.74e-05  2.21e+02
#   7500| 1.27e+04  2.39e+00  1.95e-01  3.70e+00  2.74e-05  2.26e+02
#   7750| 8.09e-01  3.29e-06  1.37e-02  1.07e+01  2.74e-05  2.31e+02
#   8000| 7.49e-01  2.92e-06  1.40e-02  1.08e+01  2.74e-05  2.37e+02
#   8250| 6.80e-01  2.67e-06  9.66e-03  1.09e+01  2.74e-05  2.42e+02
#   8500| 1.09e+01  2.74e-03  7.25e-03  1.11e+01  2.74e-05  2.48e+02
#   8750| 6.09e-01  2.45e-06  9.94e-04  1.10e+01  2.74e-05  2.53e+02
#   9000| 5.32e-01  2.14e-06  6.80e-03  1.11e+01  2.74e-05  2.60e+02
#   9250| 1.63e+01  4.13e-03  1.89e-02  1.12e+01  2.74e-05  2.66e+02
#   9500| 3.80e-01  1.74e-06  2.24e-02  1.12e+01  2.74e-05  2.72e+02
#   9750| 3.03e-01  1.46e-06  2.11e-02  1.13e+01  2.74e-05  2.78e+02
#  10000| 2.46e-01  1.29e-06  2.01e-02  1.14e+01  2.74e-05  2.83e+02
#  10250| 1.97e-01  1.64e-06  2.14e-02  1.14e+01  2.74e-05  2.89e+02
#  10500| 1.57e-01  2.01e-06  2.20e-02  1.14e+01  2.74e-05  2.96e+02
#  10750| 1.34e-01  2.23e-06  2.15e-02  1.15e+01  2.74e-05  3.02e+02
#  11000| 1.48e-01  2.07e-06  2.35e-02  1.15e+01  2.74e-05  3.09e+02
#  11250| 1.17e-01  2.41e-06  2.11e-02  1.15e+01  2.74e-05  3.16e+02
#  11500| 8.02e-02  2.78e-06  1.52e-02  1.15e+01  2.74e-05  3.22e+02
#  11750| 6.62e-02  2.91e-06  1.39e-02  1.15e+01  2.74e-05  3.28e+02
#  12000| 6.01e-02  2.94e-06  1.28e-02  1.15e+01  2.74e-05  3.34e+02
#  12250| 5.25e-02  3.00e-06  1.16e-02  1.15e+01  2.74e-05  3.40e+02
#  12500| 3.84e-02  3.17e-06  7.33e-03  1.16e+01  2.74e-05  3.46e+02
#  12750| 3.77e-02  3.12e-06  7.65e-03  1.16e+01  2.74e-05  3.52e+02
#  13000| 9.64e-02  4.57e-05  1.46e-03  1.15e+01  2.74e-05  3.58e+02
#  13250| 1.02e-01  2.38e-05  6.41e-03  1.15e+01  2.74e-05  3.64e+02
#  13275| 3.73e-02  3.36e-06  1.08e-04  1.16e+01  2.74e-05  3.64e+02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 3.64e+02s = setup: 4.06e+00s + solve: 3.60e+02s
# 	 lin-sys: 2.81e+02s, cones: 2.26e+01s, accel: 6.42e+00s
# ------------------------------------------------------------------
# objective = 11.575115
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Dec 22 02:35:57 PM: Problem status: optimal
# (CVXPY) Dec 22 02:35:57 PM: Optimal value: 1.130e+01
# (CVXPY) Dec 22 02:35:57 PM: Compilation took 4.749e+00 seconds
# (CVXPY) Dec 22 02:35:57 PM: Solver (including time spent in interface) took 3.643e+02 seconds

# %%
t_end = 10
ts = np.arange(0, t_end, dt_sim)
def f_lin(t, x):
    state, eta = x[:nx+nv], x[nx+nv:]
    state_dot = A_x @ state + A_eta @ eta[:neta_dfl]
    eta_dot = H_w_np @ x

    return np.concatenate([state_dot, eta_dot])

# state_np = np.random.uniform(-2, 2, size=(2, ))
state_np = np.array([-1, 2])
eta_np = np.array(eta_fn(state_np)).ravel()

full_state_np = np.concatenate([state_np, eta_np], axis=0)

sol = solve_ivp(
    f_np,
    (0, t_end),
    state_np,
    t_eval=ts
)

lin_sol = solve_ivp(
    f_lin,
    (0, t_end),
    full_state_np,
    t_eval=ts
)

# %%
sol.y.shape, lin_sol.y.shape
# Out:
# ((2, 10000), (23, 10000))

# %%
fig, ax = plt.subplots(3, 1, figsize=(12, 8))
# sol.y = sol.y[:, :1000]
for i in range(2):
    ax[i].plot(ts[:len(lin_sol.y[i])], lin_sol.y[i], label=f"q{i} DFL")
    ax[i].set_title('Positions')
    ax[i].plot(ts[:len(sol.y[i])], sol.y[i], label=f"q{i} real")
    ax[i].legend()
eta_sol = np.array(
    [eta_fn(state_i) for state_i in sol.y.T]
).reshape(-1, 1)
ax[2].set_title('Auxiliary Variable')
ax[2].plot(ts[:len(lin_sol.y[-1])], lin_sol.y[-1], label=f"eta DFL")
# ax[2].plot(ts, eta_sol[0], label="eta real")
ax[2].legend()
plt.show()

# %% [markdown]
# ## Regions of Attraction

# %% [markdown]
# ### LTI LQR

# %% [markdown]
# Now, let's analyse the following Lyapunov candidate:
# $$V = \frac{1}{2} \eta^T P \eta,$$
# where $P$ is a matrix, resulting from LTI LQR discrete control.

# %%
A = np.zeros(((nx+nv+neta, nx+nv+neta)))
A[:nx+nv, :nx+nv] = A_x
A[:nx+nv, nx+nv:nx+nv+neta_dfl] = A_eta
A[nx+nv:] = H_w_np

# %%
from scipy.linalg import solve_continuous_lyapunov as lyap

Q = np.eye(nx+nv+neta)
P = lyap(A.T, -Q)

# %%
def sampling_roa(f, V, dV, x_bounds, N=100):
    x_min, x_max = x_bounds
    x_range = np.array(x_max) - np.array(x_min)
    n = np.shape(x_min)[0]

    c = np.inf
    ct = []

    for i in range(N):
        x_i = x_min + x_range*np.random.rand(n)
        dV_i = dV(x_i)
        V_i = V(x_i)
        if dV_i >= 0 and V_i <= c:
            c = V_i
            ct.append(c)  
    
    return c, np.array(ct)

# %%
V = 1/2 * full_state.T @ P @ full_state
V_fn = cs.Function('V', [state], [V])
V_dot_fn = cs.Function('V_dot', [state], [cs.jacobian(V, state) @ f(state)])

# %%
state_lims = np.array([
    [-2, -2],
    [2, 2]
])

r_dfl, _ = sampling_roa(f, V_fn, V_dot_fn, state_lims, N = 10000)
levelset_dfl = cs.Function('V_level', [state], [V - r_dfl])
r_dfl
# Out:
# DM(-99.1932)

# %%
jacobian = cs.Function('jacobian', [state], [cs.jacobian(f(state), state)])
A_taylor = jacobian(np.zeros(2))
Q_taylor = np.eye(2)

P_taylor = lyap(A_taylor.T, -Q_taylor)

V_taylor = 1/2 * state.T @ P_taylor @ state
V_taylor_fn = cs.Function('V_taylor', [state], [V_taylor])
V_taylor_dot_fn = cs.Function('V_taylor', [state], [cs.jacobian(V_taylor, state) @ f(state)])

# %%
r_taylor, _ = sampling_roa(f, V_taylor_fn, V_taylor_dot_fn, state_lims, N = 10000)
levelset_taylor = cs.Function('V_level', [state], [V_taylor - r_taylor])
r_taylor
# Out:
# DM(1.17636)

# %%
phase_portrait(f, x_range=[3, 3], density=1.2)
draw_elipse(
    [-3, 3], 
    f = levelset_taylor, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'red',
    } 
)

draw_elipse(
    [-3, 3], 
    f = levelset_dfl, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'blue',
    } 
)

plt.show()
