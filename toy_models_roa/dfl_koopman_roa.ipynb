# %% [markdown]
# # DFL + Koopman applied to extended ROA analysis

# %%
from darli.models import RobotModel     # Rofl, bez nee casadi ne importiruetsya
import casadi as cs
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.integrate import solve_ivp
from utils import draw_elipse, phase_portrait, sampling_roa

# %% [markdown]
# ## Inverted time Van der Pol oscillator

# %% [markdown]
# The equation is:
# $$\ddot{x} = -(1-x^2)\dot{v} - x + u$$
#
# For the DFL linearization, let's choose:
# $$\eta = \begin{bmatrix} x^2 \dot{x} \end{bmatrix}.$$

# %% [markdown]
# If we introduce $q = \begin{bmatrix} x \\ \dot{x} \end{bmatrix}$
# Then, the equation would be:
# $$\dot{q} = \begin{bmatrix} 0 & 1 \\ -1 & -1 \end{bmatrix} q + \begin{bmatrix} 0 \\ 1 \end{bmatrix} \eta + \begin{bmatrix} 0 \\ 1 \end{bmatrix} u \equiv A_q q + A_\eta \eta + Bu$$

# %%
nx, nv = 1, 1

x = cs.SX.sym('x', nx)
v = cs.SX.sym('v', nv)
dv = cs.SX.sym('dv', nv)

state = cs.vertcat(x, v)
state_dot = cs.vertcat(v, dv)

# %%
neta_dfl = 1
neta_rbf = 20

# Inverted-time Van der Pol no. 1
# f = cs.Function("f", [state], [cs.vertcat(v, -(1-x**2)*v - x)])
# eta = x**2 * v
# A_x = np.array([[0, 1], [-1, -1]])
# A_eta = np.array([0, 1]).reshape(-1, 1)

# Inverted-time Van der Pol no. 2
f = cs.Function("f", [state], [cs.vertcat(v, -x-v + (x**3)/3)])
eta = x**3 / 3
A_x = np.array([[0, 1], [-1, -1]])
A_eta = np.array([0, 1]).reshape(-1, 1)

# Pendulum
# f = cs.Function("f", [state], [cs.vertcat(v, -9.81 * cs.sin(x))])
# eta = -cs.sin(x)
# A_x = np.array([[0, 1], [0, 0]])
# A_eta = np.array([0, 9.81]).reshape(-1, 1)

x0_range = (-1, 1)
x0 = cs.SX.sym('x0', nx+nv)
rbf = cs.Function('psi', [state, x0], [cs.norm_2(state - x0)**2 * cs.log(cs.norm_2(state - x0))])
random_rbfs = [
    rbf(state, np.random.uniform(*x0_range, size=(nx+nv))) 
    for _ in range(neta_rbf)
]
eta = cs.vertcat(eta, *random_rbfs)
neta = neta_dfl + neta_rbf

# %%
# There would be two types of symbolic etas: eta(x) and eta as free variable
# It's important to note which variable is used
eta_sym = cs.SX.sym('eta', neta)

# %%
eta_fn = cs.Function("eta", [state], [eta])

# State + auxiliary variables
full_state = cs.vertcat(state, eta)
full_state_sym = cs.vertcat(state, eta_sym)

# %%
# Verification that matrices are chosed correctly
f_lin = cs.Function("f_lin", [state], [A_x @ state + A_eta @ eta[:neta_dfl]])

state_np = np.random.uniform(-2, 2, size=(2,))

f_lin(state_np), f(state_np)
# Out:
# (DM([-1.02236, 0.777746]), DM([-1.02236, 0.777746]))

# %% [markdown]
# ### Data sampling

# %%
# Simulation parameters
dt_sim = 1e-3
dt_sample = 1e-1
n_samples = 100
t_end = 10
x_range = (-5, 5)

# %%
ts = np.arange(0, t_end, dt_sim)
save_each = int(dt_sample / dt_sim)
state_samples = []

f_np = lambda t, x: np.array(f(x)).ravel()

progress_bar = tqdm(total=n_samples)

while len(state_samples) < n_samples:
    state_np = np.random.uniform(*x_range, size=(2,))
    sol = solve_ivp(
        f_np,
        (0, t_end),
        state_np,
        t_eval=ts
    )
    if sol.status == 0:
        progress_bar.update(1)
        state_samples.append(sol.y.T[::save_each])
progress_bar.close()
# Out:
# 100%|██████████| 100/100 [00:11<00:00,  8.53it/s]

# %%
state_np = np.concatenate(state_samples, axis=0)
v_dot_np = np.array([
    f_np(0, state_i) for state_i in state_np
])

state_np.shape
# Out:
# (10000, 2)

# %%
eta_dot = cs.jacobian(eta, state) @ state_dot
eta_dot_fn = cs.Function(
    "eta_dot", 
    [state, dv], 
    [
        eta_dot
    ]
)

eta_np = np.array([
    eta_fn(state_i) for state_i in state_np
])[:, :, 0]

# %%
eta_dot_np = np.array([
    eta_dot_fn(state_i, v_dot_i[1]) for state_i, v_dot_i in zip(state_np, v_dot_np)
])[:, :, 0]

# %%
full_state_np = np.concatenate([state_np, eta_np], axis=1)

full_state_np.shape
# Out:
# (10000, 23)

# %%
full_state_dot_np = np.concatenate([v_dot_np, eta_dot_np], axis=1)

full_state_dot_np.shape
# Out:
# (10000, 23)

# %%
full_state_np.max()
# Out:
# 89.93856934538451

# %%
# Option 1: fitting only auxiliary variable's dynamics
# H_w_cp = cp.Variable((neta, nx+nv+neta))
# objective_samples = 1/len(full_state_np) * cp.sum_squares(eta_dot_np.T - H_w_cp@full_state_np.T) #+ 0.1*cp.norm(H_w_cp)

# Option 2: fitting whole dynamics
H_w_cp = cp.Variable((nx+nv+neta, nx+nv+neta))
objective_samples = cp.sum_squares(full_state_dot_np.T - H_w_cp@full_state_np.T) #+ 0.1*cp.norm(H_w_cp)

problem_samples = cp.Problem(cp.Minimize(objective_samples))
result = problem_samples.solve(verbose=True)


H_w = H_w_cp.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.1
# ===============================================================================
# (CVXPY) Jan 11 01:04:20 PM: Your problem has 529 variables, 0 constraints, and 0 parameters.
# (CVXPY) Jan 11 01:04:20 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 11 01:04:20 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 11 01:04:20 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jan 11 01:04:20 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 11 01:04:20 PM: Compiling problem (target solver=OSQP).
# (CVXPY) Jan 11 01:04:20 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Jan 11 01:04:20 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 11 01:04:20 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jan 11 01:04:20 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Jan 11 01:04:22 PM: Applying reduction OSQP
# (CVXPY) Jan 11 01:04:23 PM: Finished problem compilation (took 2.608e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 11 01:04:23 PM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 230529, constraints m = 230000
#           nnz(P) + nnz(A) = 5750000
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   5.21e+02   3.25e+06   1.00e-01   3.38e+00s
#   50   7.6245e+05   5.42e-07   4.41e-05   1.00e-01   5.34e+00s
# plsh   7.6245e+05   7.89e-11   2.71e-09   --------   8.34e+00s
#
# status:               solved
# solution polish:      successful
# number of iterations: 50
# optimal objective:    762452.2919
# run time:             8.34e+00s
# optimal rho estimate: 1.50e-02
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jan 11 01:04:31 PM: Problem status: optimal
# (CVXPY) Jan 11 01:04:31 PM: Optimal value: 7.625e+05
# (CVXPY) Jan 11 01:04:31 PM: Compilation took 2.608e+00 seconds
# (CVXPY) Jan 11 01:04:31 PM: Solver (including time spent in interface) took 8.426e+00 seconds

# %%
t_end = 10
ts = np.arange(0, t_end, dt_sim)
# def f_lin(t, x):
#     state, eta = x[:nx+nv], x[nx+nv:]
#     state_dot = A_x @ state + A_eta @ eta[:neta_dfl]
#     eta_dot = H_w @ x

#     return np.concatenate([state_dot, eta_dot])

def f_lin(t, x):
    return H_w @ x

# state_np = np.random.uniform(-2, 2, size=(2, ))
state_np = np.array([-1, 2])
eta_np = np.array(eta_fn(state_np)).ravel()

full_state_np = np.concatenate([state_np, eta_np], axis=0)

sol = solve_ivp(
    f_np,
    (0, t_end),
    state_np,
    t_eval=ts
)

lin_sol = solve_ivp(
    f_lin,
    (0, t_end),
    full_state_np,
    t_eval=ts
)

# %%
sol.y.shape, lin_sol.y.shape
# Out:
# ((2, 10000), (23, 10000))

# %%
fig, ax = plt.subplots(3, 1, figsize=(12, 8))
# sol.y = sol.y[:, :1000]
for i in range(2):
    ax[i].plot(ts[:len(lin_sol.y[i])], lin_sol.y[i], label=f"q{i} DFL")
    ax[i].set_title('Positions')
    ax[i].plot(ts[:len(sol.y[i])], sol.y[i], label=f"q{i} real")
    ax[i].legend()
eta_sol = np.array(
    [eta_fn(state_i) for state_i in sol.y.T]
).reshape(-1, 1)
ax[2].set_title('Auxiliary Variable')
ax[2].plot(ts[:len(lin_sol.y[-1])], lin_sol.y[-1], label=f"eta DFL")
# ax[2].plot(ts, eta_sol[0], label="eta real")
ax[2].legend()
plt.show()

# %% [markdown]
# ## Regions of Attraction

# %% [markdown]
# ### LTI LQR

# %% [markdown]
# Now, let's analyse the following Lyapunov candidate:
# $$V = \frac{1}{2} \eta^T P \eta,$$
# where $P$ is a matrix, resulting from LTI LQR discrete control.

# %%
# A = np.zeros(((nx+nv+neta, nx+nv+neta)))
# A[:nx+nv, :nx+nv] = A_x
# A[:nx+nv, nx+nv:nx+nv+neta_dfl] = A_eta
# A[nx+nv:] = H_w
A = H_w

# %%
from scipy.linalg import solve_continuous_lyapunov as lyap

Q = np.eye(nx+nv+neta)
P = lyap(A.T, -Q)

# %%
def is_pos_def(A):
    if np.allclose(A, A.T, rtol=1e-3):
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            print('Symmetric, but not p.d.')
            return False
    else:
        print('Not symmetric')
        return False

is_pos_def(P)
# Out:
# True

# %% [markdown]
# Let's create the following optimization problem:
# $$
# \begin{aligned}
# \min_{P_o} \quad & ||P - P_o|||_2^2\\
# \textrm{s.t.} \quad & z(0)^TP_oz(0) \geq 0\\
#   & z(x_i)^TP_oz(x_i) > 0 \quad i = 0,\ \ldots,\ N-1    \\
#   & z(x_i)^T(P_o + P_o^T)\dot{z}(x_i) \leq 0 \quad i = 0,\ \ldots,\ N-1    \\
# \end{aligned}
# $$

# %%
x_min, x_max, dx = -2, 2.01, 1e-1
x_mesh = np.array(
    np.meshgrid(
        np.arange(x_min, x_max, dx),
        np.arange(x_min, x_max, dx),
    )
).reshape(nx+nv, -1).T
x_mesh = np.concatenate([x_mesh[:len(x_mesh)//2], x_mesh[len(x_mesh)//2+1:]], axis=0)

eta_mesh = np.array(
    [eta_fn(x_mesh_i) for x_mesh_i in x_mesh]
)[:, :, 0]

state_mesh = np.concatenate([x_mesh, eta_mesh], axis=1)

state_mesh.shape
# Out:
# (1680, 23)

# %%
v_dot_mesh = np.array(
    [f_np(0, state_i) for state_i in x_mesh]
)

eta_dot_mesh = np.array(
    [eta_dot_fn(x_mesh_i, v_dot_i[-nv:]) for x_mesh_i, v_dot_i in zip(x_mesh, v_dot_mesh)]
)[:, :, 0]

state_dot_mesh = np.concatenate(
    [v_dot_mesh, eta_dot_mesh], axis=1
)

state_dot_mesh.shape
# Out:
# (1680, 23)

# %%
n_neg = 0
for i in range(len(state_mesh)):
    if state_mesh[i] @ P @ state_mesh[i] <= 0:
        n_neg += 1

print(f"Positive: {len(state_mesh)-n_neg}, negatives: {n_neg}")
# Out:
# Positive: 1680, negatives: 0

# %%
state0 = np.concatenate([np.zeros(nx+nv), np.array(eta_fn(np.zeros(nx+nv))).ravel()])

# %%
P_opt_cp = cp.Variable(P.shape)
objective_samples = 1/len(full_state_np) * cp.sum_squares(P - P_opt_cp)
constraints = [
    state_mesh_i.T @ P_opt_cp @ state_mesh_i >= 0
    for state_mesh_i in state_mesh
]
constraints += [
    state_mesh_i.T @ (P_opt_cp + P_opt_cp.T) @ state_dot_mesh_i <= 0
    for state_mesh_i, state_dot_mesh_i in zip(state_mesh, state_dot_mesh)
]
constraints.append(state0.T @ P_opt_cp @ state0 == 0)
problem_samples = cp.Problem(cp.Minimize(objective_samples), constraints)
result = problem_samples.solve(verbose=True, eps_dual_inf=1e-2, max_iter = 10000)

P_opt = P_opt_cp.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.1
# ===============================================================================
# (CVXPY) Jan 11 01:20:42 PM: Your problem has 529 variables, 3361 constraints, and 0 parameters.
# (CVXPY) Jan 11 01:20:43 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 11 01:20:43 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 11 01:20:43 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jan 11 01:20:43 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 11 01:20:43 PM: Compiling problem (target solver=OSQP).
# (CVXPY) Jan 11 01:20:43 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Jan 11 01:20:43 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 11 01:20:43 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jan 11 01:20:43 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Jan 11 01:20:50 PM: Applying reduction OSQP
# (CVXPY) Jan 11 01:20:50 PM: Finished problem compilation (took 7.627e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 11 01:20:50 PM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 1058, constraints m = 3890
#           nnz(P) + nnz(A) = 1779427
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-02,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   2.69e+05   2.69e+07   1.00e-01   9.65e-01s
#  200   9.4484e+02   5.51e+02   6.06e+00   1.02e-05   3.68e+00s
#  400   3.5185e+02   5.17e+03   2.29e-02   1.00e-06   5.68e+00s
#  600   3.7070e+02   9.08e+02   7.66e-02   1.00e-06   6.83e+00s
#  800   3.7793e+02   4.43e+02   1.99e-02   1.00e-06   7.98e+00s
# 1000   3.7981e+02   1.12e+02   1.47e-02   1.00e-06   9.13e+00s
# 1200   3.8058e+02   4.14e+02   5.24e-03   1.00e-06   1.03e+01s
# 1400   3.8614e+02   4.12e+02   1.46e-02   1.00e-06   1.15e+01s
# 1600   3.8856e+02   1.05e+02   1.02e-02   1.00e-06   1.26e+01s
# 1800   3.8883e+02   1.83e+02   7.70e-03   1.00e-06   1.38e+01s
# 2000   3.8855e+02   1.79e+02   2.76e-03   1.00e-06   1.49e+01s
# 2200   3.8825e+02   1.28e+02   1.29e-03   1.00e-06   1.61e+01s
# 2400   3.8784e+02   1.25e+02   2.27e-03   1.00e-06   1.72e+01s
# 2600   3.8749e+02   1.10e+02   1.97e-03   1.00e-06   1.84e+01s
# 2800   3.8752e+02   1.11e+01   3.50e-03   1.00e-06   1.95e+01s
# 3000   3.8737e+02   1.02e+01   2.58e-03   1.00e-06   2.07e+01s
# 3200   3.8740e+02   9.63e+00   1.09e-03   1.00e-06   2.18e+01s
# 3400   3.8743e+02   8.90e+00   2.31e-04   1.00e-06   2.30e+01s
# 3600   3.8743e+02   8.27e+00   2.68e-04   1.00e-06   2.42e+01s
# 3800   3.8750e+02   7.79e+00   2.98e-02   5.19e-06   2.61e+01s
# 4000   3.9156e+02   3.42e+00   1.73e-02   5.19e-06   2.73e+01s
# 4200   3.9513e+02   3.27e+00   1.62e-03   5.19e-06   2.84e+01s
# 4400   3.9632e+02   3.09e+00   2.59e-03   5.19e-06   2.96e+01s
# 4600   3.9686e+02   2.94e+00   1.68e-03   5.19e-06   3.08e+01s
# 4800   3.9713e+02   2.84e+00   1.32e-03   5.19e-06   3.19e+01s
# 5000   3.9723e+02   8.35e+00   1.98e-03   5.19e-06   3.31e+01s
# 5200   3.9731e+02   1.37e+01   9.99e-04   5.19e-06   3.43e+01s
# 5400   3.9735e+02   1.58e+01   7.10e-04   5.19e-06   3.55e+01s
# 5600   3.9644e+02   2.91e+01   7.90e-03   5.19e-06   3.66e+01s
# 5800   3.9624e+02   1.55e+01   9.33e-04   5.19e-06   3.78e+01s
# 6000   3.9632e+02   7.66e+00   1.95e-03   5.19e-06   3.89e+01s
# 6200   3.9632e+02   4.02e+00   4.71e-04   5.19e-06   4.01e+01s
# 6400   3.9630e+02   2.71e+00   3.02e-05   5.19e-06   4.12e+01s
# 6600   3.9630e+02   1.82e+00   1.21e-04   5.19e-06   4.24e+01s
# 6800   3.9630e+02   1.21e+00   1.49e-04   5.19e-06   4.35e+01s
# 7000   3.9630e+02   8.84e-01   8.70e-05   5.19e-06   4.47e+01s
# 7200   3.9630e+02   7.08e-01   5.10e-05   5.19e-06   4.58e+01s
# 7400   3.9630e+02   5.98e-01   3.95e-05   5.19e-06   4.70e+01s
# 7550   3.9630e+02   5.40e-01   3.36e-05   5.19e-06   4.78e+01s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 7550
# optimal objective:    396.2969
# run time:             4.78e+01s
# optimal rho estimate: 9.77e-06
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jan 11 01:21:38 PM: Problem status: optimal
# (CVXPY) Jan 11 01:21:38 PM: Optimal value: 3.963e+02
# (CVXPY) Jan 11 01:21:38 PM: Compilation took 7.627e+00 seconds
# (CVXPY) Jan 11 01:21:38 PM: Solver (including time spent in interface) took 4.786e+01 seconds

# %%
n_neg = 0
for i in range(len(state_mesh)):
    if state_mesh[i] @ P_opt @ state_mesh[i] <= 0:
        n_neg += 1

print(f"Positive: {len(state_mesh)-n_neg}, negatives: {n_neg}")
# Out:
# Positive: 1680, negatives: 0

# %%
def sampling_roa(f, V, dV, x_bounds, N=100):
    x_min, x_max = x_bounds
    x_range = np.array(x_max) - np.array(x_min)
    n = np.shape(x_min)[0]

    c = np.inf
    ct = []

    for i in range(N):
        x_i = x_min + x_range*np.random.rand(n)
        dV_i = dV(x_i)
        V_i = V(x_i)
        if dV_i >= 0 and V_i <= c:
            c = V_i
            ct.append(c)  
    
    return c, np.array(ct)

# %%
V = 1/2 * full_state.T @ P_opt @ full_state
V_fn = cs.Function('V', [state], [V])
V0 = V_fn(np.zeros(nx+nv))

V_dot_fn = cs.Function('V_dot', [state], [cs.jacobian(V, state) @ f(state)])

# %%
state_lims = np.array([
    [-2, -2],
    [2, 2]
])

r_dfl, _ = sampling_roa(f, V_fn, V_dot_fn, state_lims, N = 10000)
levelset_dfl = cs.Function('V_level', [state], [V - r_dfl])
r_dfl
# Out:
# DM(1.51998)

# %%
jacobian = cs.Function('jacobian', [state], [cs.jacobian(f(state), state)])
A_taylor = jacobian(np.zeros(2))
Q_taylor = np.eye(2)

P_taylor = lyap(A_taylor.T, -Q_taylor)

V_taylor = 1/2 * state.T @ P_taylor @ state
V_taylor_fn = cs.Function('V_taylor', [state], [V_taylor])
V_taylor_dot_fn = cs.Function('V_taylor', [state], [cs.jacobian(V_taylor, state) @ f(state)])

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-1, 1, dx)
Y = np.arange(-1, 1, dx)
x_mesh = np.meshgrid(
    X,
    Y,
)

levelset_mesh = np.array([
    [
        levelset_dfl([x_mesh[0][i, k], x_mesh[1][i, k]])
        for k in range(x_mesh[0].shape[1])
    ]   for i in range(x_mesh[0].shape[0])
])[:, :, 0, 0]

# Plot the surface.
surf = ax.plot_surface(X, Y, levelset_mesh, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
r_taylor, _ = sampling_roa(f, V_taylor_fn, V_taylor_dot_fn, state_lims, N = 10000)
levelset_taylor = cs.Function('V_level', [state], [V_taylor - r_taylor])
r_taylor
# Out:
# DM(1.93953)

# %%
fig, ax = plt.subplots()
phase_portrait(f, ax=ax, x_range=[5, 5], density=1.2)
draw_elipse(
    [-5, 5], 
    ax=ax, 
    f = levelset_taylor, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'red',
    } 
)

draw_elipse(
    [-5, 5],
    ax=ax,  
    f = levelset_dfl, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'blue',
    } 
)

plt.show()
