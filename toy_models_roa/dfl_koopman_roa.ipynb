# %% [markdown]
# # DFL + Koopman applied to extended ROA analysis

# %%
from darli.models import RobotModel     # Rofl, bez nee casadi ne importiruetsya
import casadi as cs
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.integrate import solve_ivp
from utils import draw_elipse, phase_portrait, sampling_roa

# %% [markdown]
# ## Inverted time Van der Pol oscillator

# %% [markdown]
# The equation is:
# $$\ddot{x} = -(1-x^2)\dot{v} - x + u$$
#
# For the DFL linearization, let's choose:
# $$\eta = \begin{bmatrix} x^2 \dot{x} \end{bmatrix}.$$

# %% [markdown]
# If we introduce $q = \begin{bmatrix} x \\ \dot{x} \end{bmatrix}$
# Then, the equation would be:
# $$\dot{q} = \begin{bmatrix} 0 & 1 \\ -1 & -1 \end{bmatrix} q + \begin{bmatrix} 0 \\ 1 \end{bmatrix} \eta + \begin{bmatrix} 0 \\ 1 \end{bmatrix} u \equiv A_q q + A_\eta \eta + Bu$$

# %%
nx, nv = 1, 1

x = cs.SX.sym('x', nx)
v = cs.SX.sym('v', nv)
dv = cs.SX.sym('dv', nv)

state = cs.vertcat(x, v)
state_dot = cs.vertcat(v, dv)

# %%
neta_dfl = 1
neta_rbf = 20

# Inverted-time Van der Pol no. 1
# f = cs.Function("f", [state], [cs.vertcat(v, -(1-x**2)*v - x)])
# eta = x**2 * v
# A_x = np.array([[0, 1], [-1, -1]])
# A_eta = np.array([0, 1]).reshape(-1, 1)

# Inverted-time Van der Pol no. 2
f = cs.Function("f", [state], [cs.vertcat(v, -x-v + (x**3)/3)])
eta = x**3 / 3
A_x = np.array([[0, 1], [-1, -1]])
A_eta = np.array([0, 1]).reshape(-1, 1)

# Pendulum
# f = cs.Function("f", [state], [cs.vertcat(v, -9.81 * cs.sin(x))])
# eta = -cs.sin(x)
# A_x = np.array([[0, 1], [0, 0]])
# A_eta = np.array([0, 9.81]).reshape(-1, 1)

x0_range = (-1, 1)
x0 = cs.SX.sym('x0', nx+nv)
rbf = cs.Function('psi', [state, x0], [cs.norm_2(state - x0)**2 * cs.log(cs.norm_2(state - x0))])
random_rbfs = [
    rbf(state, np.random.uniform(*x0_range, size=(nx+nv))) 
    for _ in range(neta_rbf)
]
eta = cs.vertcat(eta, *random_rbfs)
neta = neta_dfl + neta_rbf

# %%
# There would be two types of symbolic etas: eta(x) and eta as free variable
# It's important to note which variable is used
eta_sym = cs.SX.sym('eta', neta)

# %%
eta_fn = cs.Function("eta", [state], [eta])

# State + auxiliary variables
full_state = cs.vertcat(state, eta)
full_state_sym = cs.vertcat(state, eta_sym)

# %%
# Verification that matrices are chosed correctly
f_lin = cs.Function("f_lin", [state], [A_x @ state + A_eta @ eta[:neta_dfl]])

state_np = np.random.uniform(-2, 2, size=(2,))

f_lin(state_np), f(state_np)
# Out:
# (DM([-0.0663425, 0.0123836]), DM([-0.0663425, 0.0123836]))

# %% [markdown]
# ### Data sampling

# %%
# Simulation parameters
dt_sim = 1e-3
dt_sample = 1e-1
n_samples = 50
t_end = 10
x_range = (-5, 5)

# %%
ts = np.arange(0, t_end, dt_sim)
save_each = int(dt_sample / dt_sim)
state_samples = []

f_np = lambda t, x: np.array(f(x)).ravel()

progress_bar = tqdm(total=n_samples)

while len(state_samples) < n_samples:
    state_np = np.random.uniform(*x_range, size=(2,))
    sol = solve_ivp(
        f_np,
        (0, t_end),
        state_np,
        t_eval=ts
    )
    if sol.status == 0:
        progress_bar.update(1)
        state_samples.append(sol.y.T[::save_each])
progress_bar.close()
# Out:
# 100%|██████████| 50/50 [00:08<00:00,  6.02it/s]

# %%
state_np = np.concatenate(state_samples, axis=0)
v_dot_np = np.array([
    f_np(0, state_i) for state_i in state_np
])
# It's not multiple of n_samples, because some samples diverged and did not finish the iteration
state_np.shape
# Out:
# (5000, 2)

# %%
eta_dot = cs.jacobian(eta, state) @ cs.vertcat(v, dv)
eta_dot_fn = cs.Function(
    "eta_dot", 
    [state, dv], 
    [
        eta_dot
    ]
)

eta_np = np.array([
    eta_fn(state_i) for state_i in state_np
])[:, :, 0]

# %%
eta_dot_np = np.array([
    eta_dot_fn(state_i, v_dot_i[1]) for state_i, v_dot_i in zip(state_np, v_dot_np)
])[:, :, 0]

# %%
full_state_np = np.concatenate([state_np, eta_np], axis=1)

full_state_np.shape
# Out:
# (5000, 23)

# %%
full_state_np.max()
# Out:
# 80.8211870160895

# %%
H_w_cp = cp.Variable((neta, nx+nv+neta))
objective_samples = 1/len(full_state_np) * cp.sum_squares(eta_dot_np.T - H_w_cp@full_state_np.T) #+ 0.1*cp.norm(H_w_cp)
problem_samples = cp.Problem(cp.Minimize(objective_samples))
result = problem_samples.solve(verbose=True)

H_w = H_w_cp.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.1
# ===============================================================================
# (CVXPY) Jan 06 08:29:01 PM: Your problem has 483 variables, 0 constraints, and 0 parameters.
# (CVXPY) Jan 06 08:29:01 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 06 08:29:01 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 06 08:29:01 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jan 06 08:29:01 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 06 08:29:01 PM: Compiling problem (target solver=OSQP).
# (CVXPY) Jan 06 08:29:01 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Jan 06 08:29:01 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 06 08:29:01 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jan 06 08:29:01 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Jan 06 08:29:01 PM: Applying reduction OSQP
# (CVXPY) Jan 06 08:29:02 PM: Finished problem compilation (took 1.256e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 06 08:29:02 PM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 105483, constraints m = 105000
#           nnz(P) + nnz(A) = 2625000
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   3.61e+02   1.26e+06   1.00e-01   1.53e+00s
#   75   5.8881e+01   1.81e-05   3.90e-07   1.34e-04   4.91e+00s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 75
# optimal objective:    58.8814
# run time:             6.09e+00s
# optimal rho estimate: 5.33e-05
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jan 06 08:29:08 PM: Problem status: optimal
# (CVXPY) Jan 06 08:29:08 PM: Optimal value: 5.888e+01
# (CVXPY) Jan 06 08:29:08 PM: Compilation took 1.256e+00 seconds
# (CVXPY) Jan 06 08:29:08 PM: Solver (including time spent in interface) took 6.128e+00 seconds

# %%
t_end = 10
ts = np.arange(0, t_end, dt_sim)
def f_lin(t, x):
    state, eta = x[:nx+nv], x[nx+nv:]
    state_dot = A_x @ state + A_eta @ eta[:neta_dfl]
    eta_dot = H_w @ x

    return np.concatenate([state_dot, eta_dot])

# state_np = np.random.uniform(-2, 2, size=(2, ))
state_np = np.array([-1, 2])
eta_np = np.array(eta_fn(state_np)).ravel()

full_state_np = np.concatenate([state_np, eta_np], axis=0)

sol = solve_ivp(
    f_np,
    (0, t_end),
    state_np,
    t_eval=ts
)

lin_sol = solve_ivp(
    f_lin,
    (0, t_end),
    full_state_np,
    t_eval=ts
)

# %%
sol.y.shape, lin_sol.y.shape
# Out:
# ((2, 10000), (23, 10000))

# %%
fig, ax = plt.subplots(3, 1, figsize=(12, 8))
# sol.y = sol.y[:, :1000]
for i in range(2):
    ax[i].plot(ts[:len(lin_sol.y[i])], lin_sol.y[i], label=f"q{i} DFL")
    ax[i].set_title('Positions')
    ax[i].plot(ts[:len(sol.y[i])], sol.y[i], label=f"q{i} real")
    ax[i].legend()
eta_sol = np.array(
    [eta_fn(state_i) for state_i in sol.y.T]
).reshape(-1, 1)
ax[2].set_title('Auxiliary Variable')
ax[2].plot(ts[:len(lin_sol.y[-1])], lin_sol.y[-1], label=f"eta DFL")
# ax[2].plot(ts, eta_sol[0], label="eta real")
ax[2].legend()
plt.show()

# %% [markdown]
# ## Regions of Attraction

# %% [markdown]
# ### LTI LQR

# %% [markdown]
# Now, let's analyse the following Lyapunov candidate:
# $$V = \frac{1}{2} \eta^T P \eta,$$
# where $P$ is a matrix, resulting from LTI LQR discrete control.

# %%
A = np.zeros(((nx+nv+neta, nx+nv+neta)))
A[:nx+nv, :nx+nv] = A_x
A[:nx+nv, nx+nv:nx+nv+neta_dfl] = A_eta
A[nx+nv:] = H_w

# %%
from scipy.linalg import solve_continuous_lyapunov as lyap

Q = np.eye(nx+nv+neta)
P = lyap(A.T, -Q)

# %%
def is_pos_def(A):
    if np.allclose(A, A.T, rtol=1e-3):
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            print('Symmetric, but not p.d.')
            return False
    else:
        print('Not symmetric')
        return False

is_pos_def(P)
# Out:
# Symmetric, but not p.d.
# False

# %% [markdown]
# Let's create the following optimization problem:
# $$
# \begin{aligned}
# \min_{P_o} \quad & ||P - P_o|||_2^2\\
# \textrm{s.t.} \quad & z(0)^TP_oz(0) = 0\\
#   & z(x_i)^TP_oz(x_i) > 0 \quad i = 0,\ \ldots,\ N-1    \\
# \end{aligned}
# $$

# %%
eta_mesh.shape
# Out:
# (1600, 1, 1)

# %%
x_min, x_max, dx = -2, 2.01, 5e-2
x_mesh = np.array(
    np.meshgrid(
        np.arange(x_min, x_max, dx),
        np.arange(x_min, x_max, dx),
    )
).reshape(nx+nv, -1).T

x_mesh = np.concatenate([x_mesh[:len(x_mesh)//2], x_mesh[len(x_mesh)//2+1:]], axis=0)
eta_mesh = np.array(
    [eta_fn(x_mesh_i) for x_mesh_i in x_mesh]
)[:, :, 0]

state_mesh = np.concatenate([x_mesh, eta_mesh], axis=1)
state_mesh.shape
# Out:
# (6560, 23)

# %%
n_neg = 0
for i in range(len(state_mesh)):
    if state_mesh[i] @ P @ state_mesh[i] <= 0:
        n_neg += 1

print(f"Positive: {len(state_mesh)-n_neg}, negatives: {n_neg}")
# Out:
# Positive: 62, negatives: 6498

# %%
state0 = np.concatenate([np.zeros(nx+nv), np.array(eta_fn(np.zeros(nx+nv))).ravel()])

# %%
P_opt_cp = cp.Variable(P.shape)
objective_samples = 1/len(full_state_np) * cp.sum_squares(P - P_opt_cp)
constraints = [
    state_mesh_i.T @ P_opt_cp @ state_mesh_i >= 0
    for state_mesh_i in state_mesh
]
constraints.append(state0.T @ P_opt_cp @ state0 == 0)
problem_samples = cp.Problem(cp.Minimize(objective_samples), constraints)
result = problem_samples.solve(verbose=True, eps_dual_inf=1e-2, max_iter = 100000)

P_opt = P_opt_cp.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.1
# ===============================================================================
# (CVXPY) Jan 06 10:09:30 PM: Your problem has 529 variables, 6561 constraints, and 0 parameters.
# (CVXPY) Jan 06 10:09:31 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 06 10:09:31 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 06 10:09:31 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jan 06 10:09:31 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 06 10:09:31 PM: Compiling problem (target solver=OSQP).
# (CVXPY) Jan 06 10:09:31 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Jan 06 10:09:31 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 06 10:09:31 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jan 06 10:09:32 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Jan 06 10:09:59 PM: Applying reduction OSQP
# (CVXPY) Jan 06 10:10:00 PM: Finished problem compilation (took 2.881e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 06 10:10:00 PM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 1058, constraints m = 7090
#           nnz(P) + nnz(A) = 3472227
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-02,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 100000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.31e+05   1.31e+07   1.00e-01   2.73e+00s
#  200   3.5270e+05   1.86e+03   2.56e+01   3.86e-05   1.08e+01s
#  400   3.3879e+05   1.46e+02   9.80e+00   3.86e-05   1.37e+01s
#  600   3.3894e+05   1.02e+03   7.02e+00   6.27e-06   1.89e+01s
#  800   3.3497e+05   3.55e+02   2.55e+00   6.27e-06   2.18e+01s
# 1000   3.3309e+05   1.96e+02   1.11e+00   6.27e-06   2.48e+01s
# 1200   3.3338e+05   9.61e+01   5.68e-01   6.27e-06   2.78e+01s
# 1400   3.3325e+05   3.94e+01   2.87e-01   6.27e-06   3.07e+01s
# 1600   3.3312e+05   3.82e+01   1.17e-01   6.27e-06   3.36e+01s
# 1800   3.3307e+05   3.64e+01   5.37e-02   6.27e-06   3.64e+01s
# 2000   3.3318e+05   1.07e+01   3.61e-02   6.27e-06   3.94e+01s
# 2200   3.3324e+05   1.04e+01   4.27e-02   6.27e-06   4.24e+01s
# 2400   3.3324e+05   1.02e+01   4.74e-02   6.27e-06   4.54e+01s
# 2600   3.3324e+05   9.97e+00   4.89e-02   6.27e-06   4.83e+01s
# 2800   3.3325e+05   9.77e+00   4.84e-02   6.27e-06   5.10e+01s
# 3000   3.3325e+05   9.58e+00   4.77e-02   6.27e-06   5.38e+01s
# 3200   3.3326e+05   9.40e+00   4.63e-02   6.27e-06   5.68e+01s
# 3400   3.3326e+05   9.23e+00   4.47e-02   6.27e-06   6.00e+01s
# 3600   3.3327e+05   9.08e+00   4.31e-02   6.27e-06   6.27e+01s
# 3800   3.3327e+05   8.93e+00   4.15e-02   6.27e-06   6.54e+01s
# 25000   3.3347e+05   9.42e-02   4.20e-04   6.27e-06   3.51e+02s
# 25200   3.3347e+05   9.13e-02   4.07e-04   6.27e-06   3.53e+02s
# 25400   3.3347e+05   8.85e-02   3.94e-04   6.27e-06   3.56e+02s
# 25600   3.3347e+05   8.57e-02   3.82e-04   6.27e-06   3.59e+02s
# 25800   3.3347e+05   8.31e-02   3.70e-04   6.27e-06   3.62e+02s
# 26000   3.3347e+05   8.05e-02   3.59e-04   6.27e-06   3.65e+02s
# 26075   3.3347e+05   7.95e-02   3.55e-04   6.27e-06   3.66e+02s
# plsh   3.3347e+05   1.64e-09   1.02e-05   --------   3.66e+02s
#
# status:               solved
# solution polish:      successful
# number of iterations: 26075
# optimal objective:    333474.7771
# run time:             3.66e+02s
# optimal rho estimate: 1.55e-05
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jan 06 10:16:05 PM: Problem status: optimal
# (CVXPY) Jan 06 10:16:05 PM: Optimal value: 3.335e+05
# (CVXPY) Jan 06 10:16:05 PM: Compilation took 2.881e+01 seconds
# (CVXPY) Jan 06 10:16:05 PM: Solver (including time spent in interface) took 3.658e+02 seconds

# %%
def sampling_roa(f, V, dV, x_bounds, N=100):
    x_min, x_max = x_bounds
    x_range = np.array(x_max) - np.array(x_min)
    n = np.shape(x_min)[0]

    c = np.inf
    ct = []

    for i in range(N):
        x_i = x_min + x_range*np.random.rand(n)
        dV_i = dV(x_i)
        V_i = V(x_i)
        if dV_i >= 0 and V_i <= c:
            c = V_i
            ct.append(c)  
    
    return c, np.array(ct)

# %%
V = 1/2 * full_state.T @ P_opt @ full_state
V_fn = cs.Function('V', [state], [V])
V0 = V_fn(np.zeros(nx+nv))

V_dot_fn = cs.Function('V_dot', [state], [cs.jacobian(V, state) @ f(state)])

# %%
state_lims = np.array([
    [-2, -2],
    [2, 2]
])

r_dfl, _ = sampling_roa(f, V_fn, V_dot_fn, state_lims, N = 10000)
levelset_dfl = cs.Function('V_level', [state], [V - r_dfl])
r_dfl
# Out:
# DM(0.631819)

# %%
jacobian = cs.Function('jacobian', [state], [cs.jacobian(f(state), state)])
A_taylor = jacobian(np.zeros(2))
Q_taylor = np.eye(2)

P_taylor = lyap(A_taylor.T, -Q_taylor)

V_taylor = 1/2 * state.T @ P_taylor @ state
V_taylor_fn = cs.Function('V_taylor', [state], [V_taylor])
V_taylor_dot_fn = cs.Function('V_taylor', [state], [cs.jacobian(V_taylor, state) @ f(state)])

# %%
r_taylor, _ = sampling_roa(f, V_taylor_fn, V_taylor_dot_fn, state_lims, N = 10000)
levelset_taylor = cs.Function('V_level', [state], [V_taylor - r_taylor])
r_taylor
# Out:
# DM(1.95387)

# %%
fig, ax = plt.subplots()
phase_portrait(f, ax=ax, x_range=[3, 3], density=1.2)
draw_elipse(
    [-3, 3], 
    ax=ax, 
    f = levelset_taylor, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'red',
    } 
)

draw_elipse(
    [-3, 3],
    ax=ax,  
    f = levelset_dfl, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'blue',
    } 
)

plt.show()
