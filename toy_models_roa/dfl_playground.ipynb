# %% [markdown]
# # DFL applied to extended ROA analysis

# %%
from darli.models import RobotModel     # Rofl, bez nee casadi ne importiruetsya
import casadi as cs
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.integrate import solve_ivp
from utils import draw_elipse, phase_portrait, sampling_roa

# %% [markdown]
# ## Inverted time Van der Pol oscillator

# %% [markdown]
# The equation is:
# $$\dot{v} = -(1-x^2)v - x + u$$
#
# For the DFL linearization, let's choose:
# $$\eta = \begin{bmatrix} x^2 v \end{bmatrix}.$$

# %% [markdown]
# If we introduce $q = \begin{bmatrix} x \\ v \end{bmatrix}$
# Then, the equation would be:
# $$\dot{q} = \begin{bmatrix} 0 & 1 \\ -1 & -1 \end{bmatrix} q + \begin{bmatrix} 0 \\ 1 \end{bmatrix} \eta + \begin{bmatrix} 0 \\ 1 \end{bmatrix} u \equiv A_q q + A_\eta \eta + Bu$$

# %%
nx, nv, neta = 1, 1, 1

x = cs.SX.sym('x', nx)
v = cs.SX.sym('v', nv)
dv = cs.SX.sym('dv', nv)

state = cs.vertcat(x, v)
state_dot = cs.vertcat(v, dv)

# %%
# Inverted-time Van der Pol no. 1
f = cs.Function("f", [state], [cs.vertcat(v, -(1-x**2)*v - x)])
eta = x**2 * v
A_x = np.array([[0, 1], [-1, -1]])
A_eta = np.array([0, 1]).reshape(-1, 1)

# Inverted-time Van der Pol no. 2
# f = cs.Function("f", [state], [cs.vertcat(v, -x-v + (x**3)/3)])
# eta = x**3 / 3
# A_x = np.array([[0, 1], [-1, -1]])
# A_eta = np.array([0, 1]).reshape(-1, 1)

# Pendulum
# f = cs.Function("f", [state], [cs.vertcat(v, -9.81 * cs.sin(x))])
# eta = -cs.sin(x)
# A_x = np.array([[0, 1], [0, 0]])
# A_eta = np.array([0, 9.81]).reshape(-1, 1)

# %%
# There would be two types of symbolic etas: eta(x) and eta as free variable
# It's important to note where which variable is used
eta_sym = cs.SX.sym('eta', neta)

# %%
eta_fn = cs.Function("eta", [state], [eta])

# State + auxiliary variables
full_state = cs.vertcat(state, eta)
full_state_sym = cs.vertcat(state, eta_sym)

# %%
# Verification that matrices are chosed correctly
f_lin = cs.Function("f_lin", [state], [A_x @ state + A_eta @ eta])

state_np = np.random.uniform(-2, 2, size=(2,))
    
f_lin(state_np), f(state_np)
# Out:
# (DM([0.776868, 2.96094]), DM([0.776868, 2.96094]))

# %% [markdown]
# ### Data sampling

# %%
# Simulation parameters
dt_sim = 1e-3
dt_sample = 1e-1
n_samples = 500
t_end = 10
x_range = (-5, 5)

# %%
ts = np.arange(0, t_end, dt_sim)
save_each = int(dt_sample / dt_sim)
state_samples = []

f_np = lambda t, x: np.array(f(x)).ravel()

progress_bar = tqdm(total=n_samples)

while len(state_samples) < n_samples:
    state_np = np.random.uniform(*x_range, size=(2,))
    sol = solve_ivp(
        f_np,
        (0, t_end),
        state_np,
        t_eval=ts
    )
    if sol.status == 0:
        progress_bar.update(1)
        state_samples.append(sol.y.T[::save_each])
progress_bar.close()
# Out:
# 100%|██████████| 500/500 [02:13<00:00,  3.74it/s]

# %%
state_np = np.concatenate(state_samples, axis=0)
v_dot_np = np.array([
    f_np(0, state_i) for state_i in state_np
])
# It's not multiple of n_samples, because some samples diverged and did not finish the iteration
state_np.shape
# Out:
# (50000, 2)

# %%
eta_dot = cs.jacobian(eta, state) @ cs.vertcat(v, dv)
eta_dot_fn = cs.Function(
    "eta_dot", 
    [state, dv], 
    [
        eta_dot
    ]
)

eta_np = np.array([
    eta_fn(state_i) for state_i in state_np
])[:, :, 0]

# %%
eta_dot_np = np.array([
    eta_dot_fn(state_i, v_dot_i[1]) for state_i, v_dot_i in zip(state_np, v_dot_np)
])[:, :, 0]

# %%
full_state_np = np.concatenate([state_np, eta_np], axis=1)

full_state_np.shape
# Out:
# (50000, 3)

# %%
H_w_cp = cp.Variable((1, 3))
objective_samples = 1/len(full_state_np) * cp.sum_squares(eta_dot_np.T - H_w_cp@full_state_np.T)
problem_samples = cp.Problem(cp.Minimize(objective_samples))
problem_samples.solve(solver=cp.OSQP)

H_w = H_w_cp.value

# %%
def f_lin(t, x):
    state, eta = x[:-1], x[-1:]
    state_dot = A_x @ state + A_eta @ eta
    eta_dot = H_w @ x

    return np.concatenate([state_dot, eta_dot])

# state_np = np.random.uniform(-2, 2, size=(2, ))
state_np = np.array([-1, 2])
eta_np = np.array(eta_fn(state_np)).ravel()

full_state_np = np.concatenate([state_np, eta_np], axis=0)

sol = solve_ivp(
    f_np,
    (0, t_end),
    state_np,
    t_eval=ts
)

lin_sol = solve_ivp(
    f_lin,
    (0, t_end),
    full_state_np,
    t_eval=ts
)

# %%
sol.y.shape, lin_sol.y.shape
# Out:
# ((2, 10000), (3, 10000))

# %%
fig, ax = plt.subplots(3, 1, figsize=(12, 8))
# sol.y = sol.y[:, :1000]
for i in range(2):
    ax[i].plot(ts[:len(lin_sol.y[i])], lin_sol.y[i], label=f"q{i} DFL")
    ax[i].set_title('Positions')
    ax[i].plot(ts[:len(sol.y[i])], sol.y[i], label=f"q{i} real")
    ax[i].legend()
eta_sol = np.array(
    [eta_fn(state_i) for state_i in sol.y.T]
).reshape(-1, 1)
ax[2].set_title('Auxiliary Variable')
ax[2].plot(ts[:len(lin_sol.y[-1])], lin_sol.y[-1], label=f"eta DFL")
ax[2].plot(ts[:len(eta_sol)], eta_sol, label="eta real")
ax[2].legend()
plt.show()

# %% [markdown]
# ## Regions of Attraction

# %% [markdown]
# ### LTI LQR

# %% [markdown]
# $$V = \frac{1}{2} x^T P x$$

# %% [markdown]
# Now, let's analyse the following Lyapunov candidate:
# $$V = \frac{1}{2} \eta^T P \eta,$$
# where $P$ is a matrix, resulting from LTI LQR discrete control.

# %%
def is_pos_def(A):
    if np.allclose(A, A.T, rtol=1e-3):
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            print('Symmetric, but not p.d.')
            return False
    else:
        print('Not symmetric')
        return False

# %%
def sampling_roa(f, V, dV, x_bounds, N=100):
    x_min, x_max = x_bounds
    x_range = np.array(x_max) - np.array(x_min)
    n = np.shape(x_min)[0]

    c = np.inf
    ct = []

    for i in range(N):
        x_i = x_min + x_range*np.random.rand(n)
        dV_i = dV(x_i)
        V_i = V(x_i)
        if dV_i >= 0 and V_i <= c:
            c = V_i
            ct.append(c)  
    
    return c, np.array(ct)

# %%
A = np.zeros(((3, 3)))
A[:2, :2] = A_x
A[:2, 2:] = A_eta
A[2:] = H_w

# %%
from scipy.linalg import solve_continuous_lyapunov as lyap

Q = np.eye(3)
P = lyap(A.T, -Q)

# %%
P
# Out:
# array([[ 1.66768635,  0.54308274, -0.08791174],
#        [ 0.54308274,  1.39655791, -0.39399268],
#        [-0.08791174, -0.39399268,  1.92202693]])

# %%
V = full_state.T @ P @ full_state
V_fn = cs.Function('V', [state], [V])
V_dot_fn = cs.Function('V_dot', [state], [cs.jacobian(V, state) @ f(state)])

# %%
state_lims = np.array([
    [-2, -2],
    [2, 2]
])

r_dfl, _ = sampling_roa(f, V_fn, V_dot_fn, state_lims, N = 10000)
levelset_dfl = cs.Function('V_level', [state], [V - r_dfl])
r_dfl
# Out:
# DM(2.12529)

# %% [markdown]
# ## Matrix optimization via sampling

# %%
# Simulation parameters
x_range = (-2, 2)
v_range = (-2, 2)
delta = 1e-1
x_arange = np.arange(*x_range, delta)
v_arange = np.arange(*v_range, delta)
state_np = np.array(np.meshgrid(x_arange, v_arange)).reshape(2, -1).T

f_np = lambda t, x: np.array(f(x)).ravel()

# %%
state_dot_np = np.array([
    f_np(0, state_i) for state_i in state_np
])

# It's not multiple of n_samples, because some samples diverged and did not finish the iteration
state_np.shape
# Out:
# (1600, 2)

# %%
eta_dot = cs.jacobian(eta, state) @ cs.vertcat(v, dv)
eta_dot_fn = cs.Function(
    "eta_dot", 
    [state, dv], 
    [
        eta_dot
    ]
)

eta_np = np.array([
    eta_fn(state_i) for state_i in state_np
])[:, :, 0]

# %%
eta_dot_np = np.array([
    eta_dot_fn(state_i, v_dot_i[1]) for state_i, v_dot_i in zip(state_np, v_dot_np)
])[:, :, 0]

# %%
full_state_np = np.concatenate([state_np, eta_np], axis=1)
full_state_dot_np = np.concatenate([state_dot_np, eta_dot_np], axis=1)

full_state_np.shape
# Out:
# (1600, 3)

# %%
P_cp = cp.Variable(P.shape)
objective_samples = 1/len(full_state_np) * cp.sum(full_state_np @ P_cp @ full_state_dot_np.T + full_state_dot_np @ P_cp @ full_state_np.T)
constraints = [P_cp >> 0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 2
#       1 P_cp = cp.Variable(P.shape)
# ----> 2 objective_samples = 1/len(full_state_np) * cp.sum(cp.min(full_state_np @ P_cp @ full_state_dot_np.T + full_state_dot_np @ P_cp @ full_state_np.T, np.zeros((1600, ))))
#       3 constraints = [P_cp >> 0]
#
# File ~/miniconda3/envs/darli/lib/python3.10/site-packages/cvxpy/atoms/min.py:42, in min.__init__(self, x, axis, keepdims)
#      40 if isinstance(axis, cvxtypes.expression()):
#      41     raise ValueError(min.__EXPR_AXIS_ERROR__)
# ---> 42 super(min, self).__init__(x, axis=axis, keepdims=keepdims)
#
# File ~/miniconda3/envs/darli/lib/python3.10/site-packages/cvxpy/atoms/axis_atom.py:36, in AxisAtom.__init__(self, expr, axis, keepdims)
#      34 self.axis = axis
#      35 self.keepdims = keepdims
# ---> 36 super(AxisAtom, self).__init__(expr)
#
# File ~/miniconda3/envs/darli/lib/python3.10/site-packages/cvxpy/atoms/atom.py:50, in Atom.__init__(self, *args)
#      48 # Convert raw values to Constants.
#      49 self.args = [Atom.cast_to_const(arg) for arg in args]
# ---> 50 self.validate_arguments()
#      51 self._shape = self.shape_from_args()
#      52 if len(self._shape) > 2:
#
# File ~/miniconda3/envs/darli/lib/python3.10/site-packages/cvxpy/atoms/axis_atom.py:60, in AxisAtom.validate_arguments(self)
#      57 def validate_arguments(self) -> None:
#      58     """Checks that the new shape has the same number of entries as the old.
#      59     """
# ---> 60     if self.axis is not None and self.axis > self.args[0].ndim:
#      61         raise ValueError("Invalid argument for axis.")
#      62     super(AxisAtom, self).validate_arguments()
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
problem_samples = cp.Problem(cp.Minimize(objective_samples), constraints)
problem_samples.solve(verbose=True, max_iters=1000)

P_opt = P_cp.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.1
# ===============================================================================
# (CVXPY) Jan 03 07:39:10 PM: Your problem has 9 variables, 1 constraints, and 0 parameters.
# (CVXPY) Jan 03 07:39:10 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 03 07:39:10 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 03 07:39:10 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jan 03 07:39:10 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 03 07:39:10 PM: Compiling problem (target solver=SCS).
# (CVXPY) Jan 03 07:39:10 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Jan 03 07:39:10 PM: Applying reduction Dcp2Cone
# (CVXPY) Jan 03 07:39:10 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 03 07:39:10 PM: Applying reduction Dcp2Cone
# (CVXPY) Jan 03 07:39:10 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 03 07:39:10 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jan 03 07:39:15 PM: Applying reduction SCS
# (CVXPY) Jan 03 07:39:15 PM: Finished problem compilation (took 5.652e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 03 07:39:15 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 9, constraints m: 6
# cones: 	  s: psd vars: 6, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 1000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 9, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.03e+03  4.39e+01  7.23e+04 -3.61e+04  1.00e-01  1.09e-03
#     25| 8.83e+12  6.31e+03  8.63e+20 -4.31e+20  1.00e-01  1.23e-03
# ------------------------------------------------------------------
# status:  unbounded
# timings: total: 1.24e-03s = setup: 7.25e-04s + solve: 5.12e-04s
# 	 lin-sys: 8.06e-06s, cones: 9.88e-05s, accel: 1.71e-06s
# ------------------------------------------------------------------
# objective = -inf
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jan 03 07:39:15 PM: Problem status: unbounded
# (CVXPY) Jan 03 07:39:15 PM: Optimal value: -inf
# (CVXPY) Jan 03 07:39:15 PM: Compilation took 5.652e+00 seconds
# (CVXPY) Jan 03 07:39:15 PM: Solver (including time spent in interface) took 1.730e-03 seconds

# %%
V = full_state.T @ P_opt @ full_state
V_fn = cs.Function('V', [state], [V])
V_dot_fn = cs.Function('V_dot', [state], [cs.jacobian(V, state) @ f(state)])
state_lims = np.array([
    [-2, -2],
    [2, 2]
])

r_dfl, _ = sampling_roa(f, V_fn, V_dot_fn, state_lims, N = 10000)
levelset_opt = cs.Function('V_level', [state], [V - r_dfl])
r_dfl
# Out:
# DM(0.0206498)

# %% [markdown]
# ## Taylor linearization

# %%
jacobian = cs.Function('jacobian', [state], [cs.jacobian(f(state), state)])
A_taylor = jacobian(np.zeros(2))
Q_taylor = np.eye(2)

P_taylor = lyap(A_taylor.T, -Q_taylor)

V_taylor = state.T @ P_taylor @ state
V_taylor_fn = cs.Function('V_taylor', [state], [V_taylor])
V_taylor_dot_fn = cs.Function('V_taylor', [state], [cs.jacobian(V_taylor, state) @ f(state)])

# %%
r_taylor, _ = sampling_roa(f, V_taylor_fn, V_taylor_dot_fn, state_lims, N = 10000)
levelset_taylor = cs.Function('V_level', [state], [V_taylor - r_taylor])
r_taylor
# Out:
# DM(2.34785)

# %% [markdown]
# ## Visualization

# %%
fig, ax = plt.subplots()
phase_portrait(f, ax=ax, x_range=[3, 3], density=1.2)
draw_elipse(
    [-3, 3], 
    ax=ax, 
    f = levelset_taylor, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'red',
    } 
)

draw_elipse(
    [-3, 3], 
    ax=ax, 
    f = levelset_opt, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'green',
    } 
)


draw_elipse(
    [-3, 3],
    ax=ax,  
    f = levelset_dfl, 
    cs_func = True, 
    args=tuple(),
    plt_args = {
        'linewidths': 2,
        'colors': 'blue',
    } 
)

plt.show()
